# %%
import tensorflow as tf
import numpy as np

# %%
a = tf.constant([1,2,3])
print(a[2])
# Out:
# tf.Tensor(3, shape=(), dtype=int32)

# %%
print(a[0:3])
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)
