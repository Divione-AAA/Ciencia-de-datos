# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#Orientado a Objetos
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
# Gráfica de dispersión
plt.scatter(x, y, color='green', marker='o')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gráfica de dispersión")
plt.show()

# %%
# Gráfica de barras
categorias = ['A', 'B', 'C', 'D']
valores = [10, 24, 36, 18]
plt.bar(categorias, valores, color='orange')
plt.xlabel("Categorías")
plt.ylabel("Valores")
plt.title("Gráfica de barras")
plt.show()

# %%
# Histograma
datos = np.random.randn(100)
plt.hist(datos, bins=15, color='purple', alpha=0.7)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Histograma de datos aleatorios")
plt.show()

# %%
# Múltiples líneas
plt.plot(x, y, label='x^2')
plt.plot(x, np.sqrt(x), label='sqrt(x)')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Varias funciones en una gráfica")
plt.legend()
plt.show()

# %%
# Gráfica de pastel
etiquetas = ['Manzanas', 'Bananas', 'Cerezas', 'Dátiles']
cantidades = [15, 30, 45, 10]
colores = ['red', 'yellow', 'pink', 'brown']

plt.pie(cantidades, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90)
plt.title("Distribución de frutas")
plt.axis('equal')  # Para que el círculo sea perfecto
# Out:
# (np.float64(-1.0999984720247116),
#  np.float64(1.0999885359593011),
#  np.float64(-1.0999843549394943),
#  np.float64(1.0999992549971187))

# %%
plt.scatter(x,y)
