# %%
#importaciones
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#importamos el excel
train = pd.read_csv('student_data.csv')

# %%
#hacemos un pequeño analisis
sns.boxplot(x='romantic', y='G3', data=train)
plt.figure(figsize=(6, 4))
sns.boxplot(x='romantic', y='G3', data=train)
plt.title('G3 por estado romántico')
plt.show()

print(train.groupby('romantic')['G3'].mean())

plt.figure(figsize=(6, 4))
sns.boxplot(x='address', y='G3', data=train)
plt.title('G3 por tipo de dirección')
plt.show()

plt.figure(figsize=(6, 4))
sns.boxplot(x='address', y='G3', hue='romantic', data=train)
plt.title('G3 por dirección y estado romántico')
plt.show()
sns.boxplot(x='address', y='G3', data=train)
sns.boxplot(x='address', y='G3', hue='romantic', data=train)
# Out:
# romantic
# no     10.836502
# yes     9.575758
# Name: G3, dtype: float64
# <Axes: xlabel='address', ylabel='G3'>

# %%
#dejamos el algoritmo de regresión lineal

xt = train.drop('G3', axis=1)
yt = train['G3']
model = LinearRegression()
xt = pd.get_dummies(xt)
xt = xt.fillna(xt.mean())
model.fit(xt, yt)

x_train, x_val, y_train, y_val = train_test_split(xt, yt, test_size=0.2, random_state=0)
model.fit(xt, yt)
xtest = pd.get_dummies(yt)
