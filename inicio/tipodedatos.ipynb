# %%
name = "Maria"
edad = 20

# %%
print("Mi nombre es {} y mi edad es {}".format(name,edad))
# Out:
# Mi nombre es Maria y mi edad es 20

# %%
mapa = {"key1": "value1", "key2": "value2"}
#basicamente es python de siempre
