# %%
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
f1 = pd.read_csv('books.csv')
f1.head()
# Out:
#                 title            author            genre  price  stock  sold  \
# 0  The Silent Patient  Alex Michaelides         Thriller  15.99     30    12
# 1       Atomic Habits       James Clear        Self-help  18.50     25     8
# 2            Educated     Tara Westover        Biography  14.75     20     5
# 3                Dune     Frank Herbert  Science Fiction  22.00     15     7
# 4          The Hobbit    J.R.R. Tolkien          Fantasy  13.40     40    20
#
#          date
# 0  2024-06-01
# 1  2024-06-02
# 2  2024-06-03
# 3  2024-06-04
# 4  2024-06-05
