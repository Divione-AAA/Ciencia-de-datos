# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
char = ['a','b','c']
data = [10,20,30]
arr = np.array(data)
mapa = {'a':10,'b':20,'c':30}

# %%
arr
# Out:
# array([10, 20, 30])

# %%
pd.Series(data,char)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
np.random.seed(101)

# %%
np = pd.DataFrame(randn(5,4),['a','b','c','d','e'],['l','ch','i','o'])
np
# Out:
#           l        ch         i         o
# a  0.093628  1.240813 -1.097693 -1.908009
# b -0.380104 -1.666059 -2.736995  1.522562
# c  0.178009 -0.626805 -0.391089  1.743477
# d  1.130018  0.897796  0.330866 -1.063049
# e -0.125381 -0.945588  2.029544 -1.046358
