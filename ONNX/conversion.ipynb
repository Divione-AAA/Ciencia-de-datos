# %%
from tensorflow.keras.models import load_model
from onnxruntime.quantization import quantize_dynamic, QuantType
import tensorflow as tf
import tf2onnx
import onnx

# %%
model = load_model('best_malaria_cnn.h5')

# %%
model_proto = tf2onnx.convert.from_keras(
    model,
    opset=13
)

# %%
spec = (tf.TensorSpec((None, 224, 224, 3), tf.float32, name="input"),)
onnx_model, _ = tf2onnx.convert.from_keras(model,input_signature=spec, opset=13)
onnx.save(onnx_model, "modelo_convertido.onnx")

# %%
model_fp32 = './modelo_convertido.onnx'
model_quant = '/modelq.onnx'
quantize_model = quantize_dynamic(model_fp32, model_quant, weight_type = QuantType.QInt16)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[20], line 3
#       1 model_fp32 = './modelo_convertido.onnx'
#       2 model_quant = '/modelq.onnx'
# ----> 3 quantize_model = quantize_dynamic(model_fp32, model_quant, weight_type = QuantType.QInt16)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\onnxruntime\quantization\quantize.py:893, in quantize_dynamic(model_input, model_output, op_types_to_quantize, per_channel, reduce_range, weight_type, nodes_to_quantize, nodes_to_exclude, use_external_data_format, extra_options)
#     877 quantizer = ONNXQuantizer(
#     878     model,
#     879     per_channel,
#    (...)
#     889     extra_options,
#     890 )
#     892 quantizer.quantize_model()
# --> 893 quantizer.model.save_model_to_file(model_output, use_external_data_format)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\onnxruntime\quantization\onnx_model.py:451, in ONNXModel.save_model_to_file(self, output_path, use_external_data_format)
#     449 for init in self.model.graph.initializer:
#     450     self._check_init(init, "end")
# --> 451 onnx.save_model(self.model, output_path)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\onnx\__init__.py:343, in save_model(proto, f, format, save_as_external_data, all_tensors_to_one_file, location, size_threshold, convert_attribute)
#     340     proto = write_external_data_tensors(proto, basepath)
#     342 serialized = _get_serializer(format, model_filepath).serialize_proto(proto)
# --> 343 _save_bytes(serialized, f)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\onnx\__init__.py:172, in _save_bytes(content, f)
#     170 else:
#     171     f = typing.cast("str | os.PathLike", f)
# --> 172     with open(f, "wb") as writable:
#     173         writable.write(content)
#
# PermissionError: [Errno 13] Permission denied: '/modelq.onnx'
