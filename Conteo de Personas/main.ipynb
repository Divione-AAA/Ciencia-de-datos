# %%
from Data.transform import Transforms
from util.BoundingBox import BoundingBox
from util.Decoder import Decoder
from util.Metrics import DetectionMetrics
from util.NMS import NonMaximumSuppression
from Data.dataset import PeopleDataset
from models.YOLO import YOLO
from losses.yolo_loss import YOLOLoss
from callbacks.callbacks import Callbacks
from app.DatasetExplorer import DatasetExplorer
from app.DatasetAnalizer import DatasetAnalizer
from app.DatasetEstadistics import DatasetStatistics
from app.InavlidBB import InvalidBoundingBoxes
from app.ImageExplorer import ImageExplorer
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
path = "Data/"
val = ""
train = ""
test = ""
image_paths = path + "images/"
label_paths = path + "labels/"

# %%
dataset = (
    tf.data.Dataset
    .from_tensor_slices((image_paths, label_paths))
    .shuffle(1000)
    .map(
        self.parse_sample,
        num_parallel_calls=tf.data.AUTOTUNE
    )
    .cache()
    .padded_batch(
        self.batch_size,
        padded_shapes=(
            [self.image_size, self.image_size, 3],
            [None, 5]
        ),
        padding_values=(
            tf.constant(0, tf.float32),
            tf.constant(-1, tf.float32)
        )
    )
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 dataset = (
#       2     tf.data.Dataset
# ----> 3     .from_tensor_slices((image_paths, label_paths))
#       4     .shuffle(1000)
#       5     .map(
#       6         self.parse_sample,
#       7         num_parallel_calls=tf.data.AUTOTUNE
#       8     )
#       9     .cache()
#      10     .padded_batch(
#      11         self.batch_size,
#      12         padded_shapes=(
#      13             [self.image_size, self.image_size, 3],
#      14             [None, 5]
#      15         ),
#      16         padding_values=(
#      17             tf.constant(0, tf.float32),
#      18             tf.constant(-1, tf.float32)
#      19         )
#      20     )
#      21     .prefetch(tf.data.AUTOTUNE)
#      22 )
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:825, in DatasetV2.from_tensor_slices(tensors, name)
#     821 # Loaded lazily due to a circular dependency (dataset_ops ->
#     822 # from_tensor_slices_op -> dataset_ops).
#     823 # pylint: disable=g-import-not-at-top,protected-access
#     824 from tensorflow.python.data.ops import from_tensor_slices_op
# --> 825 return from_tensor_slices_op._from_tensor_slices(tensors, name)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\data\ops\from_tensor_slices_op.py:25, in _from_tensor_slices(tensors, name)
#      24 def _from_tensor_slices(tensors, name=None):
# ---> 25   return _TensorSliceDataset(tensors, name=name)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\data\ops\from_tensor_slices_op.py:38, in _TensorSliceDataset.__init__(self, element, is_files, name)
#      36 if not self._tensors:
#      37   raise ValueError("Invalid `element`. `element` should not be empty.")
# ---> 38 self._structure = nest.map_structure(
#      39     lambda component_spec: component_spec._unbatch(), batched_spec)  # pylint: disable=protected-access
#      40 self._name = name
#      42 batch_dim = tensor_shape.Dimension(
#      43     tensor_shape.dimension_value(self._tensors[0].get_shape()[0]))
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\data\util\nest.py:122, in map_structure(func, *structure, **check_types_dict)
#      92 def map_structure(func, *structure, **check_types_dict):
#      93   """Applies `func` to each entry in `structure` and returns a new structure.
#      94
#      95   Applies `func(x[0], x[1], ...)` where x[i] is an entry in
#    (...)
#     120     ValueError: If wrong keyword arguments are provided.
#     121   """
# --> 122   return nest_util.map_structure(
#     123       nest_util.Modality.DATA, func, *structure, **check_types_dict
#     124   )
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\util\nest_util.py:1068, in map_structure(modality, func, *structure, **kwargs)
#    1066   return _tf_core_map_structure(func, *structure, **kwargs)
#    1067 elif modality == Modality.DATA:
# -> 1068   return _tf_data_map_structure(func, *structure, **kwargs)
#    1069 else:
#    1070   raise ValueError(
#    1071       "Unknown modality used {} for nested structure".format(modality)
#    1072   )
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\util\nest_util.py:1135, in _tf_data_map_structure(func, *structure, **check_types_dict)
#    1132 flat_structure = (_tf_data_flatten(s) for s in structure)
#    1133 entries = zip(*flat_structure)
# -> 1135 return _tf_data_pack_sequence_as(structure[0], [func(*x) for x in entries])
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\util\nest_util.py:1135, in <listcomp>(.0)
#    1132 flat_structure = (_tf_data_flatten(s) for s in structure)
#    1133 entries = zip(*flat_structure)
# -> 1135 return _tf_data_pack_sequence_as(structure[0], [func(*x) for x in entries])
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\data\ops\from_tensor_slices_op.py:39, in _TensorSliceDataset.__init__.<locals>.<lambda>(component_spec)
#      36 if not self._tensors:
#      37   raise ValueError("Invalid `element`. `element` should not be empty.")
#      38 self._structure = nest.map_structure(
# ---> 39     lambda component_spec: component_spec._unbatch(), batched_spec)  # pylint: disable=protected-access
#      40 self._name = name
#      42 batch_dim = tensor_shape.Dimension(
#      43     tensor_shape.dimension_value(self._tensors[0].get_shape()[0]))
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\tensorflow\python\framework\tensor.py:1199, in TensorSpec._unbatch(self)
#    1197 def _unbatch(self):
#    1198   if self._shape.ndims == 0:
# -> 1199     raise ValueError("Unbatching a tensor is only supported for rank >= 1")
#    1200   return TensorSpec(self._shape[1:], self._dtype)
#
# ValueError: Unbatching a tensor is only supported for rank >= 1

# %%
DE = DatasetExplorer(path)
DA = DatasetAnalizer(path)
DS = DatasetStatistics(path)
IBB = InvalidBoundingBoxes(path)
IE = ImageExplorer(path)
