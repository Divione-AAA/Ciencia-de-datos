# %%
from app.DatasetExplorer import DatasetExplorer
from app.DatasetAnalizer import DatasetAnalizer
from app.DatasetEstadistics import DatasetStatistics
from app.InavlidBB import InvalidBoundingBoxes
from app.ImageExplorer import ImageExplorer
from app.Dataset import Dataset
from Data.dataset import PeopleDataset
from Config import CONFIG

# %%
path = "Dataset/"
DST = PeopleDataset(CONFIG)
train, valid, test = DST.load(path)

# %%
DE = DatasetExplorer(path)
DA = DatasetAnalizer(path,8)
DS = DatasetStatistics(path)
IBB = InvalidBoundingBoxes(path)
IE = ImageExplorer(path)
DST = Dataset()

# %%
DE.dataset_summary()
DE.images_without_labels()
# Out:
# DATASET SUMMARY
#
# TRAIN
# Images : 0
# Labels : 0
#
# VALID
# Images : 0
# Labels : 0
#
# TEST
# Images : 0
# Labels : 0
# TOTAL
# Images : 0
# Labels : 0
#
# Searching images without labels...
#
#
# Missing labels : 0

# %%
DE.labels_without_images()
DE.object_statistics()
# Out:
# Searching labels without image...
#
#
# Orphan labels : 0
#
# OBJECT STATISTICS
# Total objects : 0

# %%
DA.plot_people_distribution()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 DA.plot_people_distribution()
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\Conteo de Personas\app\DatasetAnalizer.py:30, in DatasetAnalizer.plot_people_distribution(self)
#      23 def plot_people_distribution(self):
#      25     """
#      26     Dibuja un histograma del número
#      27     de personas por imagen.
#      28     """
# ---> 30     people = self.people_per_image()
#      31     plt.figure(figsize=(9,5))
#      32     plt.hist(people,bins=30,edgecolor="black")
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\Conteo de Personas\app\DatasetAnalizer.py:14, in DatasetAnalizer.people_per_image(self)
#      11 def people_per_image(self):
#      13     people = []
# ---> 14     for split in self.splits:
#      15         label_dir = self.dataset_path / split / "labels"
#      16         for label in label_dir.glob("*.txt"):
#
# TypeError: 'int' object is not iterable

# %%
DA.plot_width_distribution()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 DA.plot_width_distribution()
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\Conteo de Personas\app\DatasetAnalizer.py:58, in DatasetAnalizer.plot_width_distribution(self)
#      57 def plot_width_distribution(self):
# ---> 58     widths = self.bbox_width_distribution()
#      59     plt.figure(figsize=(9,5))
#      60     plt.hist(widths,bins=40,edgecolor="black")
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\Conteo de Personas\app\DatasetAnalizer.py:47, in DatasetAnalizer.bbox_width_distribution(self)
#      40 """
#      41 Extrae el ancho de todas
#      42 las bounding boxes.
#      43 """
#      45 widths = []
# ---> 47 for split in self.splits:
#      48     label_dir = self.dataset_path / split / "labels"
#      49     for file in label_dir.glob("*.txt"):
#
# TypeError: 'int' object is not iterable
