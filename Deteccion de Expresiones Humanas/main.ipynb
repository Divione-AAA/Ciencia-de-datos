# %%
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.layers import Dense,InputLayer, Conv2D, MaxPooling2D, Dense
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.metrics import Accuracy, FalseNegatives, FalsePositives, TruePositives, TrueNegatives
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2, l1
from tensorflow.keras.callbacks import Callback, CSVLogger, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import layers, models
from model import model
from dataPrep import DatasetPreparation
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# Descargar dataset
api.dataset_download_files("muhammadhananasghar/human-emotions-datasethes", path="./data", unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/muhammadhananasghar/human-emotions-datasethes
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\urllib3\response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\urllib3\response.py:925, in HTTPResponse._raw_read(self, amt, read1)
#     915     if (
#     916         self.enforce_content_length
#     917         and self.length_remaining is not None
#    (...)
#     923         # raised during streaming, so all calls with incorrect
# ...

# %%
#Preparacion de Datos
CONFIGURATION = {
    "IM_SIZE":256,
    "CLASS_NAMES": ["angry","happy","sad"],
    "BATCH_SIZE":32,
    "SEED":None,
}

preparador = DatasetPreparation()
train = preparador.loadData("",CONFIGURATION=CONFIGURATION)
val = preparador.loadData("",CONFIGURATION=CONFIGURATION)
test = preparador.loadData("",CONFIGURATION=CONFIGURATION)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       2 CONFIGURATION = {
#       3     "IM_SIZE":256,
#       4     "CLASS_NAMES": ["angry","happy","sad"],
#       5     "BATCH_SIZE":32,
#       6     "SEED":None,
#       7 }
#       9 preparador = DatasetPreparation()
# ---> 10 train = preparador.loadData("",CONFIGURATION=CONFIGURATION)
#
# File c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\Deteccion de Expresiones Humanas\dataPrep.py:8, in DatasetPreparation.loadData(self, path, CONFIGURATION)
#       7 def loadData(self, path, CONFIGURATION):
# ----> 8     data = tf.keras.preprocessing.image_dataset_from_directory(
#       9         path,
#      10         image_size=(CONFIGURATION["IM_SIZE"], CONFIGURATION["IM_SIZE"]),
#      11         color_mode="rgb",
#      12         classname=CONFIGURATION["CLASS_NAMES"],
# ...
