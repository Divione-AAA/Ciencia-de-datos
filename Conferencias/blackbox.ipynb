# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\vpn\Documents\GitHub\Ciencia-de-datos\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
vgg_backbone = tf.keras.applications.vgg16.VGG16(
    include_top= False,
    weights= 'imagenet',
    input_shape=(36,36,3) 
)
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d6bbae143d832006294945121d1f1fc so we will re-download the data.
# ...
# 58889256/58889256 [==============================] - 1676s 28us/step

# %%
vgg_backbone.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 36, 36, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 36, 36, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 36, 36, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 18, 18, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 18, 18, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 18, 18, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
# ...
