# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10061] No se
# [nltk_data]     puede establecer una conexión ya que el equipo de
# [nltk_data]     destino denegó expresamente dicha conexión>
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10061]
# [nltk_data]     No se puede establecer una conexión ya que el equipo
# [nltk_data]     de destino denegó expresamente dicha conexión>
# False

# %%
texto = [
    "Me encanta aprender ciencia de datos",
]
stop_words_spanish = nltk.corpus.stopwords.words('spanish')
vectorizer = TfidfVectorizer(stop_words=stop_words_spanish)
X = vectorizer.fit_transform(texto)

# %%
print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['aprender' 'ciencia' 'datos' 'encanta']
# [[0.5 0.5 0.5 0.5]]
